# %% [markdown]
# <a href="https://colab.research.google.com/github/ArjnCrly/PCVK_Genap_2026/blob/main/latihan_integrasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
from PIL import Image
from skimage import io, transform

urls = [
    "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
    "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
    "https://placecats.com/800/571",
]
img_base = io.imread(url)
img_base = cv.resize(img_base, (0, 0), fx=0.5, fy=0.5)

tinggi = img_base.shape[0]
lebar = img_base.shape[1]

img_left = cv.cvtColor(img_base, cv.COLOR_BGR2RGB)
img_right = cv.cvtColor(img_base, cv.COLOR_BGR2RGB)

y_start, y_end = 100, 200
x_start, x_end = 120, 220

for i in range(y_start, y_end):
  for j in range(x_start, x_end):
    img_right[i, j] = [255, 255, 255]

final_4 = cv.hconcat((img_left, img_right))
cv2_imshow(final_4)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>
